# %%
# Dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import psycopg2

# %% [markdown]
# # Import player data

# %%
# Loading and checking all csv files and also checking for null values
players_df = pd.read_csv('Datasets/Players.csv')
players_df.head()
# Out:
#    id           Player  height  weight                 college  born  \
# 0   0     Cliff Barker     188      83  University of Kentucky  1921
# 1   1      Ralph Beard     178      79  University of Kentucky  1927
# 2   2    Charlie Black     196      90    University of Kansas  1921
# 3   3      Nelson Bobb     183      77       Temple University  1924
# 4   4  Jake Bornheimer     196      90      Muhlenberg College  1927
#
#       birth_city   birth_state
# 0       Yorktown       Indiana
# 1    Hardinsburg      Kentucky
# 2           Arco         Idaho
# 3   Philadelphia  Pennsylvania
# 4  New Brunswick    New Jersey

# %%
# Checking the data types of all columns
players_df.dtypes
# Out:
# id              int64
# Player         object
# height          int64
# weight          int64
# college        object
# born            int64
# birth_city     object
# birth_state    object
# dtype: object

# %%
# Checking the whether the the row contains null values
players_df.isna().sum()
# Out:
# id             0
# Player         0
# height         0
# weight         0
# college        0
# born           0
# birth_city     0
# birth_state    0
# dtype: int64

# %%
# Removing the special characters as a cleanup
players_df=players_df.replace('\*','',regex=True)

# %%
# Splitting player name to firstname and lastname
players_df[['first_name','last_name']] = players_df['Player'].loc[players_df['Player'].str.split().str.len() == 2].str.split(expand=True)
players_df
# Out:
#         id             Player  height  weight  \
# 0        0       Cliff Barker     188      83
# 1        1        Ralph Beard     178      79
# 2        2      Charlie Black     196      90
# 3        3        Nelson Bobb     183      77
# 4        4    Jake Bornheimer     196      90
# ...    ...                ...     ...     ...
# 3184  3184        Okaro White     203      92
# 3185  3185   Isaiah Whitehead     193      96
# 3186  3186      Troy Williams     198      97
# 3187  3187       Kyle Wiltjer     208     108
# 3188  3188  Stephen Zimmerman     213     108
#
#                               college  born      birth_city     birth_state  \
# 0              University of Kentucky  1921        Yorktown         Indiana
# 1              University of Kentucky  1927     Hardinsburg        Kentucky
# 2                University of Kansas  1921            Arco           Idaho
# 3                   Temple University  1924    Philadelphia    Pennsylvania
# 4                  Muhlenberg College  1927   New Brunswick      New Jersey
# ...                               ...   ...             ...             ...
# 3184         Florida State University  1992      Clearwater         Florida
# 3185            Seton Hall University  1995        Brooklyn        New York
# 3186  South Carolina State University  1969        Columbia  South Carolina
# 3187               Gonzaga University  1992        Portland          Oregon
# 3188  University of Nevada, Las Vegas  1996  Hendersonville       Tennessee
#
#      first_name   last_name
# 0         Cliff      Barker
# 1         Ralph       Beard
# 2       Charlie       Black
# 3        Nelson        Bobb
# 4          Jake  Bornheimer
# ...         ...         ...
# 3184      Okaro       White
# 3185     Isaiah   Whitehead
# 3186       Troy    Williams
# 3187       Kyle     Wiltjer
# 3188    Stephen   Zimmerman
#
# [3189 rows x 10 columns]

# %%
# Converting all the column heading to lower case 
players_df = players_df.rename(str.lower,axis='columns')
players_df
# Out:
#         id             player  height  weight  \
# 0        0       Cliff Barker     188      83
# 1        1        Ralph Beard     178      79
# 2        2      Charlie Black     196      90
# 3        3        Nelson Bobb     183      77
# 4        4    Jake Bornheimer     196      90
# ...    ...                ...     ...     ...
# 3184  3184        Okaro White     203      92
# 3185  3185   Isaiah Whitehead     193      96
# 3186  3186      Troy Williams     198      97
# 3187  3187       Kyle Wiltjer     208     108
# 3188  3188  Stephen Zimmerman     213     108
#
#                               college  born      birth_city     birth_state  \
# 0              University of Kentucky  1921        Yorktown         Indiana
# 1              University of Kentucky  1927     Hardinsburg        Kentucky
# 2                University of Kansas  1921            Arco           Idaho
# 3                   Temple University  1924    Philadelphia    Pennsylvania
# 4                  Muhlenberg College  1927   New Brunswick      New Jersey
# ...                               ...   ...             ...             ...
# 3184         Florida State University  1992      Clearwater         Florida
# 3185            Seton Hall University  1995        Brooklyn        New York
# 3186  South Carolina State University  1969        Columbia  South Carolina
# 3187               Gonzaga University  1992        Portland          Oregon
# 3188  University of Nevada, Las Vegas  1996  Hendersonville       Tennessee
#
#      first_name   last_name
# 0         Cliff      Barker
# 1         Ralph       Beard
# 2       Charlie       Black
# 3        Nelson        Bobb
# 4          Jake  Bornheimer
# ...         ...         ...
# 3184      Okaro       White
# 3185     Isaiah   Whitehead
# 3186       Troy    Williams
# 3187       Kyle     Wiltjer
# 3188    Stephen   Zimmerman
#
# [3189 rows x 10 columns]

# %%
# Saving the cleaned data to file 
players_df.to_csv('Datasets/c_Players.csv',index = False)

# %% [markdown]
# # Importing team data

# %%
# Loading the team csv
team_df = pd.read_csv('Datasets/nba_team_win.csv')
team_df.head()
# Out:
#       Year   Team Record   Win%
# 0  2017-18  Hawks  24-58  0.293
# 1  2016-17  Hawks  43-39  0.524
# 2  2015-16  Hawks  48-34  0.585
# 3  2014-15  Hawks  60-22  0.732
# 4  2013-14  Hawks  38-44  0.463

# %%
# Checking the data types of the columns
team_df.dtypes
# Out:
# Year       object
# Team       object
# Record     object
# Win%      float64
# dtype: object

# %%
team_df = team_df.replace({'Record' : {'12/1/1970' : '12-70','7/1/1959' : '07-59','11/1/1971' : '11-71','9/1/1941' : '09-41',
                                     '8/1/1942' : '08-42','10/1/1972':'10-72' }})

# %%
# Convert team column to string for changing the team abbreviation
# # make string version of original column, call it 'Record'
team_df['Record'] = team_df['Record'].astype(str)

# make the new columns using string indexing
team_df['wins'] = team_df['Record'].str[0:2]
team_df['losses'] = team_df['Record'].str[3:5]
        
# get rid of the extra variable (if you want)
team_df.drop('Record', axis=1, inplace=True)

# %%
# Checking whether the column contains null values
team_df.isna().sum()
# Out:
# Year      0
# Team      0
# Win%      0
# wins      0
# losses    0
# dtype: int64

# %%
# Changing the team abbreviations dictionary
teams_dict = {'Hawks':'ATL','Celtics':'BOS','Nets':'BRK','Bobcats':'CHA','Supersonic':'SEA',
             'Hornets':'CHA','Bulls':'CHI', 'Cavaliers':'CLE',
             'Mavericks':'DAL','Nuggets':'DEN','Pistons':'DET',
             'Warriors':'GSW', 'Rockets':'HOU','Pacers':'IND',
             'Clippers':'LAC','Lakers':'LAL','Grizzlies':'MEM',
             'Heat':'MIA','Bucks':'MIL', 'Timberwolves':'MIN',
             'Pelicans':'NOP', 'Knicks':'NYK', 'Thunder':'OKC',
             'Magic':'ORL','Supersonic':'SEA','76ers':'PHI','Suns':'PHX',
             'Trail Blazers':'POR','Kings':'SAC','Spurs':'SAS',
             'Raptors':'TOR','Jazz':'UTA','Wizards':'WAS','Bullets':'WAS'}

# %%
# Replacing the team name with abbreviations to match with season_stats data
team_df['Team'] = team_df['Team'].replace(teams_dict,regex=True)
team_df
# Out:
#          Year Team   Win% wins losses
# 0     2017-18  ATL  0.293   24     58
# 1     2016-17  ATL  0.524   43     39
# 2     2015-16  ATL  0.585   48     34
# 3     2014-15  ATL  0.732   60     22
# 4     2013-14  ATL  0.463   38     44
# ...       ...  ...    ...  ...    ...
# 1048  1984-85  WAS  0.488   40     42
# 1049  1983-84  WAS  0.427   35     47
# 1050  1982-83  WAS  0.512   42     40
# 1051  1981-82  WAS  0.524   43     39
# 1052  1980-81  WAS  0.476   39     43
#
# [1053 rows x 5 columns]

# %%
# Removing the special characters as a cleanup
team_df=team_df.replace('\*','',regex=True)

# %%
# Renaming  a specific column
team_df = team_df.rename(columns={'Win%':'win_percent'})

# %%
# Converting all the index names to lower cases 
team_df = team_df.rename(str.lower,axis='columns')
team_df
# Out:
#          year team  win_percent wins losses
# 0     2017-18  ATL        0.293   24     58
# 1     2016-17  ATL        0.524   43     39
# 2     2015-16  ATL        0.585   48     34
# 3     2014-15  ATL        0.732   60     22
# 4     2013-14  ATL        0.463   38     44
# ...       ...  ...          ...  ...    ...
# 1048  1984-85  WAS        0.488   40     42
# 1049  1983-84  WAS        0.427   35     47
# 1050  1982-83  WAS        0.512   42     40
# 1051  1981-82  WAS        0.524   43     39
# 1052  1980-81  WAS        0.476   39     43
#
# [1053 rows x 5 columns]

# %%
# Saving cleaned csv to file
team_df.to_csv('Datasets/c_nba_team_win.csv',index = False)

# %% [markdown]
# # Creating new dataframe to create mapping table

# %%
# Copying team column into new dataframe
team_data = team_df.filter(['team'],axis=1)
team_data
# Out:
#      team
# 0     ATL
# 1     ATL
# 2     ATL
# 3     ATL
# 4     ATL
# ...   ...
# 1048  WAS
# 1049  WAS
# 1050  WAS
# 1051  WAS
# 1052  WAS
#
# [1053 rows x 1 columns]

# %%
# Adding an auto-incrementing column 

team_data.insert(0, 'team_id', range(1, 1 + len(team_data)))
team_data
# Out:
#       team_id team
# 0           1  ATL
# 1           2  ATL
# 2           3  ATL
# 3           4  ATL
# 4           5  ATL
# ...       ...  ...
# 1048     1049  WAS
# 1049     1050  WAS
# 1050     1051  WAS
# 1051     1052  WAS
# 1052     1053  WAS
#
# [1053 rows x 2 columns]

# %%
# Saving the dataframe as csv
team_data.to_csv('Datasets/c_team.csv',index = False)

# %% [markdown]
# # Importing the season statistics data

# %%
# Loading season_stats
season_stats_df = pd.read_csv('Datasets/Seasons_Stats.csv')
season_stats_df.head()
# Out:
#    player_id  Year Pos  Age   Tm   G    TS%    FTr  OWS  DWS  ...   2P   2PA  \
# 0          0  1950  SG   29  INO  49  0.435  0.387  1.6  0.6  ...  102   274
# 1          0  1951  SG   30  INO  56  0.322  0.381 -0.9  0.7  ...   51   202
# 2          0  1952  SG   31  INO  44  0.343  0.317 -0.7  0.8  ...   48   161
# 3          1  1950   G   22  INO  60  0.422  0.301  3.6  1.2  ...  340   936
# 4          1  1951   G   23  INO  66  0.435  0.341  4.1  2.3  ...  409  1110
#
#      2P%   eFG%   FT  FTA    FT%  AST   PF   PTS
# 0  0.372  0.372   75  106  0.708  109   99   279
# 1  0.252  0.252   50   77  0.649  115   98   152
# 2  0.298  0.298   30   51  0.588   70   56   126
# 3  0.363  0.363  215  282  0.762  233  132   895
# 4  0.368  0.368  293  378  0.775  318   96  1111
#
# [5 rows x 24 columns]

# %%
# Checking for datatypes
season_stats_df.dtypes
# Out:
# player_id      int64
# Year           int64
# Pos           object
# Age            int64
# Tm            object
# G              int64
# TS%          float64
# FTr          float64
# OWS          float64
# DWS          float64
# WS           float64
# FG             int64
# FGA            int64
# FG%          float64
# 2P             int64
# 2PA            int64
# 2P%          float64
# eFG%         float64
# FT             int64
# FTA            int64
# FT%          float64
# AST            int64
# PF             int64
# PTS            int64
# dtype: object

# %%
#Checking to see any null values 
season_stats_df.isna().sum()
# Out:
# player_id    0
# Year         0
# Pos          0
# Age          0
# Tm           0
# G            0
# TS%          0
# FTr          0
# OWS          0
# DWS          0
# WS           0
# FG           0
# FGA          0
# FG%          0
# 2P           0
# 2PA          0
# 2P%          0
# eFG%         0
# FT           0
# FTA          0
# FT%          0
# AST          0
# PF           0
# PTS          0
# dtype: int64

# %%
#Renaming the specific column names
season_stats_df = season_stats_df.rename(columns={'TS%':'ts_percent','fg%':'fg_percent',
                                                 '2P':'Two_p','2PA':'Two_pa','2P%':'Twop_percent',
                                                 'eFG%':'efg_percent','FT%':'ft_percent'})
season_stats_df
# Out:
#        player_id  year pos  age   tm   g  ts_percent    ftr  ows  dws  ...  \
# 0              0  1950  SG   29  INO  49       0.435  0.387  1.6  0.6  ...
# 1              0  1951  SG   30  INO  56       0.322  0.381 -0.9  0.7  ...
# 2              0  1952  SG   31  INO  44       0.343  0.317 -0.7  0.8  ...
# 3              1  1950   G   22  INO  60       0.422  0.301  3.6  1.2  ...
# 4              1  1951   G   23  INO  66       0.435  0.341  4.1  2.3  ...
# ...          ...   ...  ..  ...  ...  ..         ...    ...  ...  ...  ...
# 20547       3186  2017  SF   22  TOT  30       0.511  0.192 -0.4  0.7  ...
# 20548       3186  2017  SF   22  MEM  24       0.474  0.203 -0.6  0.6  ...
# 20549       3186  2017  SF   22  HOU   6       0.616  0.159  0.2  0.1  ...
# 20550       3187  2017  PF   24  HOU  14       0.437  0.143 -0.1  0.1  ...
# 20551       3188  2017   C   20  ORL  19       0.346  0.161 -0.1  0.1  ...
#
#        two_p  two_pa  twop_percent  efg_percent   ft  fta  ft_percent  ast  \
# 0        102     274         0.372        0.372   75  106       0.708  109
# 1         51     202         0.252        0.252   50   77       0.649  115
# 2         48     161         0.298        0.298   30   51       0.588   70
# 3        340     936         0.363        0.363  215  282       0.762  233
# 4        409    1110         0.368        0.368  293  378       0.775  318
# ...      ...     ...           ...          ...  ...  ...         ...  ...
# 20547     55     105         0.524        0.491   21   32       0.656   25
# 20548     41      82         0.500        0.455   15   25       0.600   19
# 20549     14      23         0.609        0.591    6    7       0.857    6
# 20550      0       1         0.000        0.429    1    2       0.500    2
# 20551     10      31         0.323        0.323    3    5       0.600    4
#
#         pf   pts
# 0       99   279
# 1       98   152
# 2       56   126
# 3      132   895
# 4       96  1111
# ...    ...   ...
# 20547   60   185
# 20548   42   127
# 20549   18    58
# 20550    4    13
# 20551   17    23
#
# [20552 rows x 24 columns]

# %%
# Converting index names to lower cases just to maintain consistency 
season_stats_df = season_stats_df.rename(str.lower,axis='columns')
season_stats_df
# Out:
#        player_id  year pos  age   tm   g  ts_percent    ftr  ows  dws  ...  \
# 0              0  1950  SG   29  INO  49       0.435  0.387  1.6  0.6  ...
# 1              0  1951  SG   30  INO  56       0.322  0.381 -0.9  0.7  ...
# 2              0  1952  SG   31  INO  44       0.343  0.317 -0.7  0.8  ...
# 3              1  1950   G   22  INO  60       0.422  0.301  3.6  1.2  ...
# 4              1  1951   G   23  INO  66       0.435  0.341  4.1  2.3  ...
# ...          ...   ...  ..  ...  ...  ..         ...    ...  ...  ...  ...
# 20547       3186  2017  SF   22  TOT  30       0.511  0.192 -0.4  0.7  ...
# 20548       3186  2017  SF   22  MEM  24       0.474  0.203 -0.6  0.6  ...
# 20549       3186  2017  SF   22  HOU   6       0.616  0.159  0.2  0.1  ...
# 20550       3187  2017  PF   24  HOU  14       0.437  0.143 -0.1  0.1  ...
# 20551       3188  2017   C   20  ORL  19       0.346  0.161 -0.1  0.1  ...
#
#        two_p  two_pa  twop_percent  efg_percent   ft  fta  ft_percent  ast  \
# 0        102     274         0.372        0.372   75  106       0.708  109
# 1         51     202         0.252        0.252   50   77       0.649  115
# 2         48     161         0.298        0.298   30   51       0.588   70
# 3        340     936         0.363        0.363  215  282       0.762  233
# 4        409    1110         0.368        0.368  293  378       0.775  318
# ...      ...     ...           ...          ...  ...  ...         ...  ...
# 20547     55     105         0.524        0.491   21   32       0.656   25
# 20548     41      82         0.500        0.455   15   25       0.600   19
# 20549     14      23         0.609        0.591    6    7       0.857    6
# 20550      0       1         0.000        0.429    1    2       0.500    2
# 20551     10      31         0.323        0.323    3    5       0.600    4
#
#         pf   pts
# 0       99   279
# 1       98   152
# 2       56   126
# 3      132   895
# 4       96  1111
# ...    ...   ...
# 20547   60   185
# 20548   42   127
# 20549   18    58
# 20550    4    13
# 20551   17    23
#
# [20552 rows x 24 columns]

# %%
# Filtering records from 1979 onwards
filtered_year = season_stats_df[season_stats_df['year'] >= 1979 ]
filtered_year
# Out:
#        player_id  year pos  age   tm   g  ts_percent    ftr  ows  dws  ...  \
# 1037         236  1980  SG   22  POR  72       0.443  0.196 -0.8  1.1  ...
# 1038         236  1981  SG   23  POR  79       0.564  0.227  5.6  2.1  ...
# 1039         236  1982  SG   24  POR  82       0.561  0.228  5.6  1.8  ...
# 1040         236  1983  SG   25  POR  81       0.573  0.361  7.8  2.4  ...
# 1041         236  1984  SG   26  POR  81       0.573  0.310  7.5  1.9  ...
# ...          ...   ...  ..  ...  ...  ..         ...    ...  ...  ...  ...
# 20547       3186  2017  SF   22  TOT  30       0.511  0.192 -0.4  0.7  ...
# 20548       3186  2017  SF   22  MEM  24       0.474  0.203 -0.6  0.6  ...
# 20549       3186  2017  SF   22  HOU   6       0.616  0.159  0.2  0.1  ...
# 20550       3187  2017  PF   24  HOU  14       0.437  0.143 -0.1  0.1  ...
# 20551       3188  2017   C   20  ORL  19       0.346  0.161 -0.1  0.1  ...
#
#        two_p  two_pa  twop_percent  efg_percent   ft  fta  ft_percent  ast  \
# 1037     188     438         0.429        0.412   64   90       0.711  144
# 1038     583    1062         0.549        0.537  182  248       0.734  299
# 1039     654    1223         0.535        0.529  220  287       0.767  276
# 1040     678    1298         0.522        0.517  388  478       0.812  231
# 1041     663    1263         0.525        0.521  345  410       0.841  251
# ...      ...     ...           ...          ...  ...  ...         ...  ...
# 20547     55     105         0.524        0.491   21   32       0.656   25
# 20548     41      82         0.500        0.455   15   25       0.600   19
# 20549     14      23         0.609        0.591    6    7       0.857    6
# 20550      0       1         0.000        0.429    1    2       0.500    2
# 20551     10      31         0.323        0.323    3    5       0.600    4
#
#         pf   pts
# 1037    97   443
# 1038   172  1354
# 1039   159  1552
# 1040   160  1756
# 1041   165  1722
# ...    ...   ...
# 20547   60   185
# 20548   42   127
# 20549   18    58
# 20550    4    13
# 20551   17    23
#
# [16366 rows x 24 columns]

# %%
# Saving the csv to a file 
filtered_year.to_csv('Datasets/c_Seasonsstats.csv',index = False)

# %% [markdown]
# # Create database connection

# %%
# Create PostgreSQL RDS Database Connection
conn_string = "postgres:{pwd}@database-4.ciwsxcnlf2n2.us-east-2.rds.amazonaws.com:5432/SportsData"
engine = create_engine(f'postgresql://{conn_string}')

# %%
# Check table names
engine.table_names()
# Out:
# ['nba_team_record', 'season_stats', 'teams', 'players']

# %%
import csv
with open('Datasets/c_Players.csv') as csvfile:
    myCSVReader = csv.DictReader(csvfile)

    # change names in placeholder to match names in csv file.
    sql = """INSERT INTO players(id,player,height,weight,college,born,birth_city,birth_state,firstname,lastname)
          VALUES (%(id)s,%(player)s,%(height)s,%(weight)s,%(college)s,%(born)s,%(birth_city)s,%(birth_state)s,%(first_name)s,%(last_name)s)"""

    for row in myCSVReader:
        # use row directly
        engine.execute(sql, row)

# %%
with open('Datasets/c_nba_team_win.csv') as csvfile:
    myCSVReader = csv.DictReader(csvfile)

    # change names in placeholder to match names in csv file.
    sql = """INSERT INTO nba_team_record(year,team,wins,losses,win_percent)
          VALUES (%(year)s,%(team)s,%(wins)s,%(losses)s,%(win_percent)s)"""

    for row in myCSVReader:
        # use row directly
        engine.execute(sql, row)

# %%
with open('Datasets/c_Seasonsstats.csv') as csvfile:
    myCSVReader = csv.DictReader(csvfile)

    # change names in placeholder to match names in csv file.
    sql = """INSERT INTO season_stats(player_id,year,pos,age,tm,g,ts_percent,ftr,ows,dws,ws,fg,fga,fg_percent,two_p,two_pa,twop_percent,efg_percent,ft,fta,ft_percent,ast,pf,pts)
          VALUES(%(player_id)s,%(year)s,%(pos)s,%(age)s,%(tm)s,%(g)s,%(ts_percent)s,%(ftr)s,%(ows)s,%(dws)s,%(ws)s,%(fg)s,%(fga)s,%(fg_percent)s,%(two_p)s,%(two_pa)s,%(twop_percent)s,%(efg_percent)s,%(ft)s,%(fta)s,%(ft_percent)s,%(ast)s,%(pf)s,%(pts)s)"""

    for row in myCSVReader:
        # use row directly
        engine.execute(sql, row)

# %%
import csv
with open('Datasets/c_team.csv') as csvfile:
    myCSVReader = csv.DictReader(csvfile)

    # change names in placeholder to match names in csv file.
    sql = """INSERT INTO teams(team_id,team_name)
          VALUES(%(team_id)s,%(team)s)"""

    for row in myCSVReader:
        # use row directly
        engine.execute(sql, row)

# %% [markdown]
# # Reading data from aws postgres to Pandas

# %%
pd.read_sql_query('select * from players', con=engine).head()
# Out:
#    id           player  height  weight                 college  born  \
# 0   0     Cliff Barker     188      83  University of Kentucky  1921
# 1   1      Ralph Beard     178      79  University of Kentucky  1927
# 2   2    Charlie Black     196      90    University of Kansas  1921
# 3   3      Nelson Bobb     183      77       Temple University  1924
# 4   4  Jake Bornheimer     196      90      Muhlenberg College  1927
#
#       birth_city   birth_state firstname    lastname
# 0       Yorktown       Indiana     Cliff      Barker
# 1    Hardinsburg      Kentucky     Ralph       Beard
# 2           Arco         Idaho   Charlie       Black
# 3   Philadelphia  Pennsylvania    Nelson        Bobb
# 4  New Brunswick    New Jersey      Jake  Bornheimer

# %%
pd.read_sql_query('select * from nba_team_record', con=engine).head()
# Out:
#       year team wins  losses  win_percent
# 0  2017-18  ATL   24      58        0.293
# 1  2016-17  ATL   43      39        0.524
# 2  2015-16  ATL   48      34        0.585
# 3  2014-15  ATL   60      22        0.732
# 4  2013-14  ATL   38      44        0.463

# %%
pd.read_sql_query('select * from Season_Stats', con=engine).head()
# Out:
#    player_id  year pos  age   tm   g  ts_percent    ftr  ows  dws  ...  two_p  \
# 0        236  1980  SG   22  POR  72       0.443  0.196 -0.8  1.1  ...  188.0
# 1        236  1981  SG   23  POR  79       0.564  0.227  5.6  2.1  ...  583.0
# 2        236  1982  SG   24  POR  82       0.561  0.228  5.6  1.8  ...  654.0
# 3        236  1983  SG   25  POR  81       0.573  0.361  7.8  2.4  ...  678.0
# 4        236  1984  SG   26  POR  81       0.573  0.310  7.5  1.9  ...  663.0
#
#    two_pa  twop_percent  efg_percent     ft  fta  ft_percent    ast     pf  \
# 0   438.0         0.429        0.412   64.0   90       0.711  144.0   97.0
# 1  1062.0         0.549        0.537  182.0  248       0.734  299.0  172.0
# 2  1223.0         0.535        0.529  220.0  287       0.767  276.0  159.0
# 3  1298.0         0.522        0.517  388.0  478       0.812  231.0  160.0
# 4  1263.0         0.525        0.521  345.0  410       0.841  251.0  165.0
#
#       pts
# 0   443.0
# 1  1354.0
# 2  1552.0
# 3  1756.0
# 4  1722.0
#
# [5 rows x 24 columns]

# %%
pd.read_sql_query('select * from teams', con=engine).head()
# Out:
#    team_id team_name
# 0        1       ATL
# 1        2       ATL
# 2        3       ATL
# 3        4       ATL
# 4        5       ATL
